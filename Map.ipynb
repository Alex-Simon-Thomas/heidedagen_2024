# %%
from folium import Map, Marker, Popup, Circle
import pandas as pd

# %%
#import the airports data from the airports.csv file
airports = pd.read_csv('airports.csv')
airports.head()
# Out:
#   destinations     city            dutch   latitude  longitude
# 0          LCY   London      Londen City  51.504266   0.054902
# 1          LTN   London     Londen Luton  51.878102  -0.366425
# 2          LGW   London   Londen Gatwick  51.154108  -0.182312
# 3          LHR   London  Londen Heathrow  51.467739  -0.458780
# 4          BRS  Bristol          Bristol  51.382970  -2.718624

# %%
map = Map(location=[52.3080392, 4.7621975], zoom_start=4)

# add a marker for each airport
for index, row in airports.iterrows():
    marker = Marker(location=[row['latitude'], row['longitude']])
    popup = Popup(row['dutch'])
    popup.add_to(marker)
    marker.add_to(map)

# add a marker for Amsterdam Schiphol Airport
marker = Marker(location=[52.3080392, 4.7621975])
popup = Popup("Amsterdam Schiphol Airport")
popup.add_to(marker)
marker.add_to(map)

# add a circle for Amsterdam Schiphol Airport
circle = Circle(location=[52.3080392, 4.7621975], radius=(1000*1900), color="red", fill=False)
circle.add_to(map)

# map.save('map.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9f9e0d18a47c44d5ee261eeee365251 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9f9e0d18a47c44d5ee261eeee365251&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9f9e0d18a47c44d5ee261eeee365251 = L.map(
#                 &quot;map_d9f9e0d18a47c44d5ee261eeee365251&quot;,
#                 {
#                     center: [52.3080392, 4.7621975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d58ac4237573333ac2ef5d6233f1ce98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d58ac4237573333ac2ef5d6233f1ce98.addTo(map_d9f9e0d18a47c44d5ee261eeee365251);
#
#
#             var marker_6c97a199298182183c69c5e06aeee490 = L.marker(
#                 [51.5042655, 0.0549024013303768],
#                 {}
#             ).addTo(map_d9f9e0d18a47c44d5ee261eeee365251);
#
#
#         var popup_4f833ffb42c2bb892a883e638fdfb5fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7277e582173bb8a206cad863abfcb62f = $(`&lt;div id=&quot;html_7277e582173bb8a206cad863abfcb62f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londen City&lt;/div&gt;`)[0];
#                 popup_4f833ffb42c2bb892a883e638fdfb5fe.setContent(html_7277e582173bb8a206cad863abfcb62f);
#
#
#
#         marker_6c97a199298182183c69c5e06aeee490.bindPopup(popup_4f833ffb42c2bb892a883e638fdfb5fe)
#         ;
#
#
#
#
#             var marker_a55ae1f1d8794e433eb081bf1f9839e5 = L.marker(
#                 [51.87810155, -0.3664254744086523],
#                 {}
#             ).addTo(map_d9f9e0d18a47c44d5ee261eeee365251);
#
#
#         var popup_a74e9e091dc038270fd3cbcb7a12c310 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_097787881a143179f7e4e66cc97ba97f = $(`&lt;div id=&quot;html_097787881a143179f7e4e66cc97ba97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londen Luton&lt;/div&gt;`)[0];
#                 popup_a74e9e091dc038270fd3cbcb7a12c310.setContent(html_097787881a143179f7e4e66cc97ba97f);
#
#
#
#         marker_a55ae1f1d8794e433eb081bf1f9839e5.bindPopup(popup_a74e9e091dc038270fd3cbcb7a12c310)
#         ;
#
#
#
#
#             var marker_4330d3859747b934ea8fe6fee27a5286 = L.marker(
#                 [51.1541082, -0.1823116499127204],
#                 {}
#             ).addTo(map_d9f9e0d18a47c44d5ee261eeee365251);
#
#
#         var popup_1cf803018a717fa3815d19201498ed42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c09fee22ba8fb071c19b4756e2b9b97c = $(`&lt;div id=&quot;html_c09fee22ba8fb071c19b4756e2b9b97c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londen Gatwick&lt;/div&gt;`)[0];
#                 popup_1cf803018a717fa3815d19201498ed42.setContent(html_c09fee22ba8fb071c19b4756e2b9b97c);
#
#
#
#         marker_4330d3859747b934ea8fe6fee27a5286.bindPopup(popup_1cf803018a717fa3815d19201498ed42)
#         ;
#
#
#
#
#             var marker_975c4ff0e3e482ffc5452c7fd59fc244 = L.marker(
#                 [51.46773895, -0.4587800741571181],
#                 {}
#             ).addTo(map_d9f9e0d18a47c44d5ee261eeee365251);
#
#
#         var popup_183bc230beb04e1e94e8a77c5f64899c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d4e19c3d679480676130207f3a0b8c1 = $(`&lt;div id=&quot;html_3d4e19c3d679480676130207f3a0b8c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londen Heathrow&lt;/div&gt;`)[0];
#                 popup_183bc230beb04e1e94e8a77c5f64899c.setContent(html_3d4e19c3d679480676130207f3a0b8c1);
#
#
#
#         marker_975c4ff0e3e482ffc5452c7fd59fc244.bindPopup(popup_183bc230beb04e1e94e8a77c5f64899c)
#         ;
#
#
#
#
#             var marker_9bb185a12ac5bf28b70085da42e1d8ad = L.marker(
#                 [51.38296995, -2.7186237715618864],
#                 {}
#             ).addTo(map_d9f9e0d18a47c44d5ee261eeee365251);
#
#
#         var popup_c4b4267fc7f12517cac9d3b395878fe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_392a17282b013c96a19ac188bb515519 = $(`&lt;div id=&quot;html_392a17282b013c96a19ac188bb515519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bristol&lt;/div&gt;`)[0];
#                 popup_c4b4267fc7f12517cac9d3b395878fe3.setContent(html_392a17282b013c96a19ac188bb515519);
#
#
#
#         marker_9bb185a12ac5bf28b70085da42e1d8ad.bindPopup(popup_c4b4267fc7f12517cac9d3b395878fe3)
#         ;
#
#
#
#
#             var marker_12ec9514b7cfcda550378137fcb46409 = L.marker(
#                 [46.23781635, 6.108121245519259],
#                 {}
