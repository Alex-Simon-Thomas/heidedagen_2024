# %%
# Importing the required modules
from folium import Map, Marker, Popup, Circle
import pandas as pd
from settings import Settings

# Creating an instance of the Settings class
settings = Settings()

# Importing the airports data from the airports.csv file
airports = pd.read_csv(f"{settings.data_dir}/airports.csv")

# Dropping duplicates based on the "city" column
airports = airports.drop_duplicates(subset="city")

# %%
map = Map(location=[52.3080392, 4.7621975], zoom_start=4)

# add a marker for each airport
for index, row in airports.iterrows():
    marker = Marker(location=[row['latitude'], row['longitude']])
    popup = Popup(row['dutch'])
    popup.add_to(marker)
    marker.add_to(map)

# add a marker for Amsterdam Schiphol Airport
marker = Marker(location=[52.3080392, 4.7621975])
popup = Popup("Amsterdam Schiphol Airport")
popup.add_to(marker)
marker.add_to(map)

# add a circle for Amsterdam Schiphol Airport
circle = Circle(location=[52.3080392, 4.7621975], radius=(1000*1900), color="red", fill=False)
circle.add_to(map)

map.save('map.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e36d544c9069837cb3b6420a0cb2a9a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e36d544c9069837cb3b6420a0cb2a9a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e36d544c9069837cb3b6420a0cb2a9a2 = L.map(
#                 &quot;map_e36d544c9069837cb3b6420a0cb2a9a2&quot;,
#                 {
#                     center: [52.3080392, 4.7621975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4af05d185eaee1d4d27e966068d467d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f4af05d185eaee1d4d27e966068d467d.addTo(map_e36d544c9069837cb3b6420a0cb2a9a2);
#
#
#             var marker_b8723337dff94a1e11ef02f60eef578c = L.marker(
#                 [51.5042655, 0.0549024013303768],
#                 {}
#             ).addTo(map_e36d544c9069837cb3b6420a0cb2a9a2);
#
#
#         var popup_07c9dae30787dca226c9374687187919 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f5d03544b2e36cccc967eb2fa3ec5b4 = $(`&lt;div id=&quot;html_9f5d03544b2e36cccc967eb2fa3ec5b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Londen City&lt;/div&gt;`)[0];
#                 popup_07c9dae30787dca226c9374687187919.setContent(html_9f5d03544b2e36cccc967eb2fa3ec5b4);
#
#
#
#         marker_b8723337dff94a1e11ef02f60eef578c.bindPopup(popup_07c9dae30787dca226c9374687187919)
#         ;
#
#
#
#
#             var marker_07996b858e9fc37fc32c4bf7381deb2f = L.marker(
#                 [51.38296995, -2.7186237715618864],
#                 {}
#             ).addTo(map_e36d544c9069837cb3b6420a0cb2a9a2);
#
#
#         var popup_b675ea696ab49353c8556f4a26e3161c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eba4661238724610d21b1bb843bb1f1c = $(`&lt;div id=&quot;html_eba4661238724610d21b1bb843bb1f1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bristol&lt;/div&gt;`)[0];
#                 popup_b675ea696ab49353c8556f4a26e3161c.setContent(html_eba4661238724610d21b1bb843bb1f1c);
#
#
#
#         marker_07996b858e9fc37fc32c4bf7381deb2f.bindPopup(popup_b675ea696ab49353c8556f4a26e3161c)
#         ;
#
#
#
#
#             var marker_ba22778853dba08341a45dcce1c2a876 = L.marker(
#                 [46.23781635, 6.108121245519259],
#                 {}
#             ).addTo(map_e36d544c9069837cb3b6420a0cb2a9a2);
#
#
#         var popup_77f0251ff041a10b3eb750d94949404d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fa08c1f415a6617e4451650701f3949 = $(`&lt;div id=&quot;html_6fa08c1f415a6617e4451650701f3949&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Geneve&lt;/div&gt;`)[0];
#                 popup_77f0251ff041a10b3eb750d94949404d.setContent(html_6fa08c1f415a6617e4451650701f3949);
#
#
#
#         marker_ba22778853dba08341a45dcce1c2a876.bindPopup(popup_77f0251ff041a10b3eb750d94949404d)
#         ;
#
#
#
#
#             var marker_b5782c7dda2cdcb58980f17e3119afc0 = L.marker(
#                 [47.7934551, 13.001830576958724],
#                 {}
#             ).addTo(map_e36d544c9069837cb3b6420a0cb2a9a2);
#
#
#         var popup_ec04e61f6b555f2b82363fab5b9fe606 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d8e1d9109010676269f6dc0a58e7238 = $(`&lt;div id=&quot;html_7d8e1d9109010676269f6dc0a58e7238&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Salzburg&lt;/div&gt;`)[0];
#                 popup_ec04e61f6b555f2b82363fab5b9fe606.setContent(html_7d8e1d9109010676269f6dc0a58e7238);
#
#
#
#         marker_b5782c7dda2cdcb58980f17e3119afc0.bindPopup(popup_ec04e61f6b555f2b82363fab5b9fe606)
#         ;
#
#
#
#
#             var marker_ca4a106465c31bc1c2263c71baf85e59 = L.marker(
#                 [45.6296273, 8.723547468967393],
#                 {}
#             ).addTo(map_e36d544c9069837cb3b6420a0cb2a9a2);
#
#
#         var popup_34b8102612ce4c56872b0655bed48f42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e4d0593453ba7512061985e87789846 = $(`&lt;div id=&quot;html_6e4d0593453ba7512061985e87789846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Milaan Malpensa&lt;/div&gt;`)[0];
#                 popup_34b8102612ce4c56872b0655bed48f42.setContent(html_6e4d0593453ba7512061985e87789846);
#
#
#
#         marker_ca4a106465c31bc1c2263c71baf85e59.bindPopup(popup_34b8102612ce4c56872b0655bed48f42)
#         ;
#
#
#
#
#             var marker_93a7a722d634b1a318166d5e4c036ff7 = L.marker(
#                 [45.50353855, 12.342579681064803],
#                 {}
#             ).addTo(m
